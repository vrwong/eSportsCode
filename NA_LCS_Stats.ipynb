# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
PO_Data = []
Orator = pd.read_csv('C:\Users\Victor\Desktop\Self_Shit\Oracles_Elixer_Data\NALCS_Playoffs_Team_Data_2016_24_8.csv',sep = ',')
PO_Data.append(Orator)
print Orator
#PO_Data = pd.concat(PO_Data,axis=1)
#PO_Data_Transpose = np.transpose(np.array(PO_Data))
#PO_Data_Transpose
# Out:
#                    Team  Games Played  Wins  Losses  Average Game Time  Kills  \
# 0               Cloud 9             9     6       3               38.3    168
# 1  Counter Logic Gaming             7     3       4               36.4     75
# 2                EnVyUs             4     1       3               34.7     36
# 3             Immortals             5     2       3               41.1     61
# 4           Team Liquid             4     1       3               33.3     47
# 5          Team SoloMid             3     3       0               40.4     37
#
#    Deaths   K:D  CKPM     GSPD  ...     FT%  F3T%  HLD%  FBN%   BN%   JNG%  \
# 0      97  1.73  0.77    0.077  ...    0.44  0.56  0.11  0.67  0.73  0.486
# 1      84  0.89  0.62   -0.008  ...    0.71  0.71  0.29  0.20  0.20  0.505
# 2      84  0.43  0.86  -19.40%  ...    0.50  0.25  0.00  0.00  0.17  0.464
# 3      87  0.70  0.71    0.017  ...    0.60  0.60  0.00  0.60  0.33  0.554
# ...

# %%
PO_Data_Top = []
Orator_Top = pd.read_csv('C:\Users\Victor\Desktop\Self_Shit\Oracles_Elixer_Data\NA_LCS_2016_SUMMER_PLAYOFFS_PLAYER_STATS_TOP.csv',sep = ',')
PO_Data_Top.append(Orator_Top)
PO_Data_Top = pd.concat(PO_Data_Top,axis=1)
PO_Data_Top
# Out:
#      Player                  Team  GP    W%   K   D   A  KDA     KP   DTH%  \
# 0   Darshan  Counter Logic Gaming   7  0.43  16  14  28  3.1  0.587  0.167
# 1  Hauntzer         Team Solo Mid   3  1.00   9   4  21  7.5  0.811  0.250
# 2      Huni             Immortals   5  0.40  17  24  27  1.8  0.721  0.276
# 3    Impact               Cloud 9   9  0.67  32  30  76  3.6  0.643  0.309
# 4    Lourlo           Team Liquid   4  0.25   8  23   9  1.4  0.362  0.203
# 5    Seraph                EnVyUs   4  0.25  10  17  16  1.5  0.722  0.202
#
#    ...   CSD@10  GD@10  CSPM  CS%P15  DPM   DMG%   EGPM  GOLD%   WPM  WCPM
# 0  ...      2.4     47    47   0.241  402  0.205  222.7  0.210  0.51  0.18
# 1  ...     -1.3     74    74   0.279  587  0.281  312.3  0.235  0.51  0.06
# 2  ...      2.8      0     0   0.281  771  0.294   28.5  0.242  0.50  0.13
# 3  ...     -2.8    -19   -19   0.257  558  0.243  259.4  0.213  0.50  0.14
# ...

# %%
PO_Data_Jungle = []
Orator_Jungle = pd.read_csv('C:\Users\Victor\Desktop\Self_Shit\Oracles_Elixer_Data\NA_LCS_2016_SUMMER_PLAYOFFS_PLAYER_STATS_Jungle.csv',sep = ',')
PO_Data_Jungle.append(Orator_Jungle)
PO_Data_Jungle = pd.concat(PO_Data_Jungle,axis=1)
PO_Data_Jungle
# Out:
#        Player                  Team  GP    W%   K   D   A  KDA     KP   DTH%  \
# 0     Dardoch           Team Liquid   4  0.25   8  10  22  3.0  0.638  0.169
# 1      Meteos               Cloud 9   9  0.67  29  15  79  7.2  0.643  0.155
# 2     Procxin                EnVyUs   4  0.25   3  15  26  1.9  0.806  0.179
# 3   Reignover             Immortals   5  0.40  18  13  29  3.6  0.770  0.149
# 4  Svenskeren         Team Solo Mid   3  1.00   2   3  24  8.7  0.703  0.188
# 5     Xmithie  Counter Logic Gaming   7  0.43  11  15  37  3.2  0.640  0.179
#
#    ...   CSD@10  GD@10  CSPM  CS%P15  DPM   DMG%   EGPM  GOLD%   WPM  WCPM
# 0  ...     -5.0   -463   4.4   0.170  374  0.225  206.9  0.209  0.66  0.41
# 1  ...     -1.3      3   3.8   0.123  353  0.155  229.9  0.188  0.81  0.44
# 2  ...      0.8    -77   4.0   0.150  326  0.162  180.4  0.194  0.60  0.28
# 3  ...      1.8     56   4.3   0.136  417  0.166  229.4  0.193  0.99  0.46
# ...

# %%
PO_Data_Mid = []
Orator_Mid = pd.read_csv('C:\Users\Victor\Desktop\Self_Shit\Oracles_Elixer_Data\NA_LCS_2016_SUMMER_PLAYOFFS_PLAYER_STATS_Mid.csv',sep = ',')
PO_Data_Mid.append(Orator_Mid)
PO_Data_Mid = pd.concat(PO_Data_Mid,axis=1)
PO_Data_Mid
# Out:
#      Player                  Team  GP    W%   K   D   A  KDA     KP   DTH%  \
# 0  Bjergsen         Team SoloMid0   3  1.00  17   3  11  9.3  0.757  0.188
# 1     Fenix           Team Liquid   4  0.25  15  12  12  2.3  0.574  0.203
# 2      Huhi  Counter Logic Gaming   7  0.43  15  19  29  2.3  0.587  0.226
# 3    Jensen               Cloud 9   9  0.67  70  16  54  7.8  0.738  0.165
# 4     Ninja                EnVyUs   4  0.25  11  23  12  1.0  0.639  0.274
# 5  Pobelter             Immortals   5  0.40  11  21  30  2.0  0.672  0.241
#
#    ...   CSD@10  GD@10   CSPM  CS%P15  DPM   DMG%   EGPM  GOLD%   WPM  WCPM
# 0  ...      9.0    292  9.500   0.261  492  0.239  310.1  0.233  0.41  0.12
# 1  ...      5.5    121  0.279   0.287  515  0.297  242.1  0.249  0.31  0.08
# 2  ...     -7.0   -195  0.281   0.294  508  0.258  243.3  0.229  0.50  0.21
# 3  ...      5.3    196  0.257   0.303  648  0.282  309.2  0.252  0.40  0.15
# ...

# %%
PO_Data_ADC = []
Orator_ADC = pd.read_csv('C:\Users\Victor\Desktop\Self_Shit\Oracles_Elixer_Data\NA_LCS_2016_SUMMER_PLAYOFFS_PLAYER_STATS_ADC.csv',index_col='Player',sep = ',')
PO_Data_ADC.append(Orator_ADC)
PO_Data_ADC = pd.concat(PO_Data_ADC,axis=1)
PO_Data_ADC
# Out:
#                             Team  GP    W%   K   D   A  KDA     KP   DTH%  \
# Player
# Doublelift          Team SoloMid   3  1.00   7   4  19  6.5  0.703  0.250
# fabbbyyy             Team Liquid   2  0.00   2   7  10  1.7  0.571  0.219
# Jynthe               Team Liquid   2  0.50   7   6   7  2.3  0.538  0.222
# LOD                       EnVyUs   4  0.25  10  14  17  1.9  0.750  0.167
# Sneaky                   Cloud 9   9  0.67  32  14  94  9.0  0.750  0.144
# Stixxay     Counter Logic Gaming   7  0.43  30  20  27  2.9  0.760  0.238
# WildTurtle             Immortals   5  0.40  14  16  25  2.4  0.639  0.184
#
#              FB%  CSD@10  GD@10  CSPM  CS%P15  DPM   DMG%   EGPM  GOLD%   WPM  \
# Player
# Doublelift  0.00    -4.3   -175   9.7   0.286  500  0.259  301.7  0.227  0.43
# fabbbyyy    0.00    -0.5   -134   6.6   0.248  358  0.212  180.8  0.199  0.31
# Jynthe      0.00    -1.0   -654   7.0   0.219  397  0.212  234.2  0.218  0.39
# ...

# %%
PO_Data_ADC['WPM']
# Out:
# Player
# Doublelift    0.43
# fabbbyyy      0.31
# Jynthe        0.39
# LOD           0.20
# Sneaky        0.31
# Stixxay       0.37
# WildTurtle    0.38
# Name: WPM, dtype: float64

# %%
PO_Data
# Out:
#                    Team  Games Played  Wins  Losses  Average Game Time  Kills  \
# 0               Cloud 9             9     6       3               38.3    168
# 1  Counter Logic Gaming             7     3       4               36.4     75
# 2                EnVyUs             4     1       3               34.7     36
# 3             Immortals             5     2       3               41.1     61
# 4           Team Liquid             4     1       3               33.3     47
# 5          Team SoloMid             3     3       0               40.4     37
#
#    Deaths   K:D  CKPM     GSPD  ...     FT%  F3T%  HLD%  FBN%   BN%   JNG%  \
# 0      97  1.73  0.77    0.077  ...    0.44  0.56  0.11  0.67  0.73  0.486
# 1      84  0.89  0.62   -0.008  ...    0.71  0.71  0.29  0.20  0.20  0.505
# 2      84  0.43  0.86  -19.40%  ...    0.50  0.25  0.00  0.00  0.17  0.464
# 3      87  0.70  0.71    0.017  ...    0.60  0.60  0.00  0.60  0.33  0.554
# ...

# %%
PO_Data_Supp = []
Orator_Supp = pd.read_csv('C:\Users\Victor\Desktop\Self_Shit\Oracles_Elixer_Data\NA_LCS_2016_SUMMER_PLAYOFFS_PLAYER_STATS_Supp.csv',sep = ',')
PO_Data_Supp.append(Orator_Supp)
PO_Data_Supp = pd.concat(PO_Data_Supp,axis=1)
PO_Data_Supp
# Out:
#      Player                  Team  GP    W%  K   D    A   KDA     KP   DTH%  \
# 0    Adrian             Immortals   5  0.40  1  13   43   3.4  0.720  0.149
# 1  aphromoo  Counter Logic Gaming   7  0.43  3  16   54   3.6  0.760  0.190
# 2  Biofrost          Team SoloMid   3  1.00  2   2   28  15.0  0.811  0.125
# 3    Hakuho                EnVyUs   4  0.25  2  15   23   1.7  0.694  0.179
# 4      Matt           Team Liquid   4  0.25  7  12   20   2.3  0.574  0.203
# 5  Smoothie              Cloud 9    9  0.67  5  22  108   5.1  0.673  0.227
#
#    ...   CSD@10  GD@10  CSPM  CS%P15  DPM   DMG%   EGPM  GOLD%   WPM  WCPM
# 0  ...      1.2    -16   1.4   0.049  107  0.043  135.1  0.114  1.72  0.34
# 1  ...     -9.1     32   0.4   0.016  130  0.066  118.5  0.109  1.18  0.27
# 2  ...     11.0     27   1.4   0.036  126  0.061  150.3  0.113  1.44  0.51
# 3  ...     -3.3    -35   0.8   0.035  193  0.101  118.3  0.128  1.16  0.23
# ...
